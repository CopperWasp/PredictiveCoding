# %%
import pandas as pd
import numpy as np

# %%
# define the data directorty 
file = '/Users/jeevithanalagurajah/Downloads/Books.csv'

# %%
# create pandas frame
data = pd.read_csv(file ,delimiter=',',header=None,names=["Item", "User", "Rating", "Time_stamp"])

# %%
# drop Time_stamp column 
data = data.drop('Time_stamp', axis=1)

# %%
data.head(5)
# Out:
#          Item            User  Rating
# 0  0001713353  A1C6M8LCIX4M6M     5.0
# 1  0001713353  A1REUF3A1YCPHM     5.0
# 2  0001713353   A1YRBRK2XM5D5     5.0
# 3  0001713353  A1V8ZR5P78P4ZU     5.0
# 4  0001713353  A2ZB06582NXCIV     5.0

# %%
# tranfrom user as features and fill NAs with 0.
trans_data = data.pivot_table('Rating', ['Item'], 'User').fillna(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-df18680a36a9> in <module>
# ----> 1 trans_data = data.pivot_table('Rating', ['Item'], 'User').fillna(0)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#    6068         from pandas.core.reshape.pivot import pivot_table
#    6069
# -> 6070         return pivot_table(
#    6071             self,
#    6072             values=values,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#     130             else:
#     131                 to_unstack.append(name)
# --> 132         table = agged.unstack(to_unstack)
#     133
#     134     if not dropna:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in unstack(self, level, fill_value)
#    6384         from pandas.core.reshape.reshape import unstack
#    6385
# -> 6386         return unstack(self, level, fill_value)
#    6387
#    6388     _shared_docs[
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/reshape.py in unstack(obj, level, fill_value)
#     406     if isinstance(obj, DataFrame):
#     407         if isinstance(obj.index, MultiIndex):
# --> 408             return _unstack_frame(obj, level, fill_value=fill_value)
#     409         else:
#     410             return obj.T.stack(dropna=False)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/reshape.py in _unstack_frame(obj, level, fill_value)
#     430         return obj._constructor(blocks)
#     431     else:
# --> 432         unstacker = _Unstacker(
#     433             obj.values,
#     434             obj.index,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/reshape.py in __init__(self, values, index, level, value_columns, fill_value, constructor)
#     136
#     137         if num_rows > 0 and num_columns > 0 and num_cells <= 0:
# --> 138             raise ValueError("Unstacked DataFrame is too big, causing int32 overflow")
#     139
#     140         self._make_sorted_values_labels()
#
# ValueError: Unstacked DataFrame is too big, causing int32 overflow

# %%
trans_data
# Out:
# User        A0095461J2PRARAMDCI  A0097695AYLE91ZX89FB  A01423305PUDQS2VV7QX  \
# Item
# 1619923009                  0.0                   0.0                   0.0
# B001BKEWF2                  0.0                   0.0                   0.0
# B001GXRQW0                  0.0                   0.0                   0.0
# B001H53QE4                  0.0                   0.0                   0.0
# B001H53QEO                  0.0                   0.0                   0.0
# ...                         ...                   ...                   ...
# B01GMFJ8JU                  0.0                   0.0                   0.0
# B01GOQHGL4                  0.0                   0.0                   0.0
# B01GOQIKRI                  0.0                   0.0                   0.0
# B01GP1W4LA                  0.0                   0.0                   0.0
# B01H5PPJT4                  0.0                   0.0                   0.0
#
# User        A0151652BYTK45B15T2R  A0155528TCZ6R6URPU31  A01660245RTS7EI29B68  \
# Item
# 1619923009                   0.0                   0.0                   0.0
# B001BKEWF2                   0.0                   0.0                   0.0
# B001GXRQW0                   0.0                   0.0                   0.0
# B001H53QE4                   0.0                   0.0                   0.0
# B001H53QEO                   0.0                   0.0                   0.0
# ...                          ...                   ...                   ...
# B01GMFJ8JU                   0.0                   0.0                   0.0
# B01GOQHGL4                   0.0                   0.0                   0.0
# B01GOQIKRI                   0.0                   0.0                   0.0
# B01GP1W4LA                   0.0                   0.0                   0.0
# B01H5PPJT4                   0.0                   0.0                   0.0
#
# User        A0173750PFTTV2DMHIPE  A0175754Z0N88R7YTDUJ  A01862287VQU9OZPV4HS  \
# Item
# 1619923009                   0.0                   0.0                   0.0
# B001BKEWF2                   0.0                   0.0                   0.0
# B001GXRQW0                   0.0                   0.0                   0.0
# B001H53QE4                   0.0                   0.0                   0.0
# B001H53QEO                   0.0                   0.0                   0.0
# ...                          ...                   ...                   ...
# B01GMFJ8JU                   0.0                   0.0                   0.0
# B01GOQHGL4                   0.0                   0.0                   0.0
# B01GOQIKRI                   0.0                   0.0                   0.0
# B01GP1W4LA                   0.0                   0.0                   0.0
# B01H5PPJT4                   0.0                   0.0                   0.0
#
# User        A0239841P9KD1PM0XKXT  ...  AZZQ2GIKDSZLN  AZZQEHFVAGRLU  \
# Item                              ...
# 1619923009                   0.0  ...            0.0            0.0
# B001BKEWF2                   0.0  ...            0.0            0.0
# B001GXRQW0                   0.0  ...            0.0            0.0
# B001H53QE4                   0.0  ...            0.0            0.0
# B001H53QEO                   0.0  ...            0.0            0.0
# ...                          ...  ...            ...            ...
# B01GMFJ8JU                   0.0  ...            0.0            0.0
# B01GOQHGL4                   0.0  ...            0.0            0.0
# B01GOQIKRI                   0.0  ...            0.0            0.0
# B01GP1W4LA                   0.0  ...            0.0            0.0
# B01H5PPJT4                   0.0  ...            0.0            0.0
#
# User        AZZQKE13BD5HE  AZZT1ERHBSNQ8  AZZT4YW3W1W3S  AZZVIIME2080X  \
# Item
# 1619923009            0.0            0.0            0.0            0.0
# B001BKEWF2            0.0            0.0            0.0            0.0
# B001GXRQW0            0.0            0.0            0.0            0.0
# B001H53QE4            0.0            0.0            0.0            0.0
# B001H53QEO            0.0            0.0            0.0            0.0
# ...                   ...            ...            ...            ...
# B01GMFJ8JU            0.0            0.0            0.0            0.0
# B01GOQHGL4            0.0            0.0            0.0            0.0
# B01GOQIKRI            0.0            0.0            0.0            0.0
# B01GP1W4LA            0.0            0.0            0.0            0.0
# B01H5PPJT4            0.0            0.0            0.0            0.0
#
# User        AZZVLL8QF9TKK  AZZWGZAX7ILXP  AZZX1A14KXATV  AZZZRGMYLGFLM
# Item
# 1619923009            0.0            0.0            0.0            0.0
# B001BKEWF2            0.0            0.0            0.0            0.0
# B001GXRQW0            0.0            0.0            0.0            0.0
# B001H53QE4            0.0            0.0            0.0            0.0
# B001H53QEO            0.0            0.0            0.0            0.0
# ...                   ...            ...            ...            ...
# B01GMFJ8JU            0.0            0.0            0.0            0.0
# B01GOQHGL4            0.0            0.0            0.0            0.0
# B01GOQIKRI            0.0            0.0            0.0            0.0
# B01GP1W4LA            0.0            0.0            0.0            0.0
# B01H5PPJT4            0.0            0.0            0.0            0.0
#
# [1548 rows x 128877 columns]
